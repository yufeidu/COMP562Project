# %%
# Imports
import functools
from multiprocessing import Pool
import opensmile
import pandas as pd
from pathlib import Path
import soundfile as sf

# %%
# Worker function
def featureWorker(audioPath, smile, label):
    df = None
    with audioPath.open('rb') as file:
        data, samplerate = sf.read(file)
        for i in range(int(data.shape[0]/samplerate/30)):
            name = audioPath.name.replace('.mp3', '').replace('.flac', '') + '_' + str(i)
            subData = data[i*samplerate*30:(i+1)*samplerate*30, 1]
            if df is None:
                df = smile.process_signal(subData, samplerate)
                df['name'] = [name]
                df['label'] = [label]
                df = df.set_index(['name', 'label'])
            else:
                tempDf = smile.process_signal(subData, samplerate)
                tempDf['name'] = [name]
                tempDf['label'] = [label]
                tempDf = tempDf.set_index(['name', 'label'])
                df = pd.concat([df, tempDf])
    return df

# %%
# Test worker function
# Only for debugging, do not run when generating the dataset
data, samplerate = sf.read('dataset/MP3_to_FLAC_insanely_high/001-Endwalker.mp3.flac')
df = None
smile = opensmile.Smile(
    feature_set = opensmile.FeatureSet.ComParE_2016,
    feature_level = opensmile.FeatureLevel.Functionals,
)
# Extract features for each 30 seconds
# Ignore snippets under 30 seconds
for i in range(int(data.shape[0]/samplerate/30)):
    filename = 'Test_' + str(i)
    subData = data[i*samplerate*30:(i+1)*samplerate*30, 1]
    if df is None:
        df = featureWorker(subData, samplerate, smile)
        df['name'] = [filename]
        df = df.set_index('name')
    else:
        print('Adding')
        tempDf = featureWorker(subData, samplerate, smile)
        tempDf['name'] = [filename]
        tempDf = tempDf.set_index('name')
        df = pd.concat([df, tempDf])
df
# Out:
# Adding
# Adding
# Adding
# Adding
#         F0semitoneFrom27.5Hz_sma3nz_amean  \
# name
# Test_0                          18.277109
# Test_1                          18.932316
# Test_2                          18.917887
# Test_3                          18.820414
# Test_4                          19.925528
#
#         F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# name
# Test_0                                0.211671
# Test_1                                0.226265
# Test_2                                0.320817
# Test_3                                0.228321
# Test_4                                0.312412
#
#         F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# name
# Test_0                                   15.964147
# Test_1                                   15.517254
# Test_2                                   15.583258
# Test_3                                   16.858976
# Test_4                                   17.017380
#
#         F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# name
# Test_0                                   18.645599
# Test_1                                   19.041876
# Test_2                                   18.412197
# Test_3                                   18.807341
# Test_4                                   18.581041
#
#         F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# name
# Test_0                                   20.490549
# Test_1                                   22.269821
# Test_2                                   19.159142
# Test_3                                   19.145868
# Test_4                                   20.152973
#
#         F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# name
# Test_0                                  4.526402
# Test_1                                  6.752567
# Test_2                                  3.575884
# Test_3                                  2.286892
# Test_4                                  3.135593
#
#         F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# name
# Test_0                                   162.687912
# Test_1                                   161.841034
# Test_2                                   308.761871
# Test_3                                   121.434937
# Test_4                                   163.498901
#
#         F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# name
# Test_0                                     197.854248
# Test_1                                     163.118103
# Test_2                                     556.804077
# Test_3                                     124.874252
# Test_4                                     186.520416
#
#         F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  \
# name
# Test_0                                    113.263168
# Test_1                                    117.282478
# Test_2                                    167.305450
# Test_3                                    160.076996
# Test_4                                    209.951843
#
#         F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope  ...  \
# name                                                    ...
# Test_0                                      103.828979  ...
# Test_1                                      136.512329  ...
# Test_2                                      179.005753  ...
# Test_3                                      290.345245  ...
# Test_4                                      440.281647  ...
#
#         slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# name
# Test_0                  -0.027175                     -0.013031
# Test_1                  -0.033687                     -0.015582
# Test_2                  -0.026049                     -0.005922
# Test_3                  -0.037341                     -0.017632
# Test_4                  -0.032492                     -0.012355
#
#         spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  \
# name
# Test_0                     4.122325             2.934311
# Test_1                     6.106512             3.401134
# Test_2                     6.681701             5.035012
# Test_3                     8.209599             4.668223
# Test_4                     8.315269             5.568523
#
#         VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# name
# Test_0              2.242303                    0.375522
# Test_1              2.440655                    0.334658
# Test_2              2.805611                    0.154048
# Test_3              4.209823                    0.120079
# Test_4              4.243235                    0.097402
#
#         StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# name
# Test_0                      0.556882                   0.071136
# Test_1                      0.391618                   0.072453
# Test_2                      0.200886                   0.219855
# Test_3                      0.114445                   0.105826
# Test_4                      0.080825                   0.125714
#
#         StddevUnvoicedSegmentLength  equivalentSoundLevel_dBp
# name
# Test_0                     0.063001                -14.361074
# Test_1                     0.053936                 -9.601865
# Test_2                     0.299165                 -8.946024
# Test_3                     0.105113                 -8.319811
# Test_4                     0.155009                 -8.117042
#
# [5 rows x 88 columns]

# %%
# Input paths
losslessPath = Path('dataset/All_44KHz_lossless')
lossyPath = Path('dataset/MP3_to_FLAC_insanely_high')
# Output paths
smileFeaturePath = Path('dataset/opensmile_features.csv')

# Construct dataset
df = None
# Initialize opensmile
smile = opensmile.Smile(
    feature_set = opensmile.FeatureSet.ComParE_2016,
    feature_level = opensmile.FeatureLevel.Functionals,
)

# %%
# Go through lossless files
featureLossless = functools.partial(featureWorker, smile=smile, label=0)

with Pool() as pool:
    results = pool.imap(featureLossless, losslessPath.iterdir(), chunksize=50)
    for resultDf in results:
        if df is None:
            df = resultDf
        else:
            df = pd.concat([df, resultDf])

# %%
df.index
# Out:
# MultiIndex([(                      '031-芒種、鼠黐の薫風_0', 0),
#             (                      '031-芒種、鼠黐の薫風_1', 0),
#             (                      '031-芒種、鼠黐の薫風_2', 0),
#             (                      '031-芒種、鼠黐の薫風_3', 0),
#             (                      '031-芒種、鼠黐の薫風_4', 0),
#             (                      '031-芒種、鼠黐の薫風_5', 0),
#             (                      '031-芒種、鼠黐の薫風_6', 0),
#             (                      '031-芒種、鼠黐の薫風_7', 0),
#             (                      '031-芒種、鼠黐の薫風_8', 0),
#             (                      '031-芒種、鼠黐の薫風_9', 0),
#             ...
#             ( '046-遊園施設 (From NieR_Automata).mp3_4', 1),
#             (                     '31_知恵を絞って.mp3_0', 1),
#             (                     '31_知恵を絞って.mp3_1', 1),
#             (                     '31_知恵を絞って.mp3_2', 1),
#             (                     '31_知恵を絞って.mp3_3', 1),
#             ('20 SPRING RIGHTEOUSNESS –首都・蜀–.mp3_0', 1),
#             ('20 SPRING RIGHTEOUSNESS –首都・蜀–.mp3_1', 1),
#             ('20 SPRING RIGHTEOUSNESS –首都・蜀–.mp3_2', 1),
#             ('20 SPRING RIGHTEOUSNESS –首都・蜀–.mp3_3', 1),
#             ('20 SPRING RIGHTEOUSNESS –首都・蜀–.mp3_4', 1)],
#            names=['name', 'label'], length=13755)

# %%
# Go through lossy files
featureLossy = functools.partial(featureWorker, smile=smile, label=1)

with Pool() as pool:
    results = pool.imap(featureLossy, lossyPath.iterdir(), chunksize=50)
    for resultDf in results:
        if df is None:
            df = resultDf
        else:
            df = pd.concat([df, resultDf])

# %%
# Write feature to file
df.to_csv(smileFeaturePath)
